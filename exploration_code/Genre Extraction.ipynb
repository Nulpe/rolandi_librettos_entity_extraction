# %%
import pandas as pd
import re
from nltk.cluster import KMeansClusterer
import nltk
import numpy as np
import spacy
from sklearn.cluster import KMeans
from tqdm import tqdm
import requests

# %%
# load file

locations = pd.read_csv('./data/librettos_theaters.csv', delimiter='\t')
locations['id'] = [int(re.findall(r'\d+', s)[0]) for s in locations.file_name]
locations = locations.drop(columns=['Unnamed: 0'])
locations.sample(5)
# Out:
#           file_name                                              title  date  \
# 819   data_935.json  Medea. tragedia lirica in tre atti da rapprese...  1850
# 283   data_601.json  L' amore costante, commedia per musica in quat...  1787
# 677   data_217.json  Erminia, farsa giocosa per musica del sig. L. ...  1805
# 547   data_302.json  Gli avventurieri, opera buffa in due atti da r...  1842
# 1022  data_376.json  Il Pastor fido, tragicomedia pastorale del sig...  1784
#
#                                                 coperta  \
# 819   ['—', '_', '_', 'ey', 'PLES', 'ae', ')', 'ro',...
# 283   ['{', 'foartedi', '“Sova', 'nn', '!', ')', 'Po...
# 677   ['f', '\\', 'LOCO', 'SOCHEOOOOS', 'F', ':', 'E...
# 547   ['GLI', 'AVVENTURIERI', 'OPERA', 'BUFFA', '18'...
# 1022  ['3', 'Qi', 'x', 'Galore', 'icy', 'Toe', 'PASS...
#
#                           pot_city_name  coperta_appended city_name  latitude  \
# 819                                  []                 0         0   0.00000
# 283                                  []                 0         0   0.00000
# 677                ['livorn', 'casale']                 0    livorn  43.54427
# 547   ['venezia', 'venezia', 'venetia']                 0   venezia  45.43713
# 1022  ['venezia', 'venezia', 'venetia']                 1   venezia  45.43713
#
#       longitude                pot_city_name_fuzzy  ...  \
# 819     0.00000                                 []  ...
# 283     0.00000                                 []  ...
# 677    10.32615              ['livorn', 'venezia']  ...
# 547    12.33265  ['venezia', 'venezia', 'venetia']  ...
# 1022   12.33265  ['venezia', 'venezia', 'venetia']  ...
#
#       predicted_cluster_method_1 inferred_latitude inferred_longitude  \
# 819                            3        45.4337096         12.3338572
# 283                           73         Not found          Not found
# 677                            4        41.1297436          14.783396
# 547                            3        45.4337096         12.3338572
# 1022                           1         Not found          Not found
#
#                                    title_opera_method_1 title_opera_method_2  \
# 819                                               Medea                Medea
# 283                                   L' amore costante            Not found
# 677                                             Erminia              Erminia
# 547                                    Gli avventurieri            Not found
# 1022  Il Pastor fido, tragicomedia pastorale del sig...          Pastor fido
#
#                                      title_vec_method_1  \
# 819   [ 5.0539675   3.0430608  10.380463   -4.242064...
# 283   [ 0.448929    0.53146785  2.7469213  -2.901008...
# 677   [ 6.9308467   3.0184045   9.5799885  -4.379949...
# 547   [-2.6041934e+00  3.1466422e+00  4.8280487e+00 ...
# 1022  [ 0.5116386   0.69495374  2.4874156   0.542860...
#
#      predicted_title_cluster_method_1                             composer  \
# 819                               251                            Not found
# 283                                59                            Not found
# 677                               126  musica del sig. L. G. Buonavoglia l
# 547                                 7             maestro Antonio Buzzolla
# 1022                              156                            Not found
#
#                                          inferred_title title_mediawiki_pageid
# 819                                               Medea                 691887
# 283                                   L' amore costante                2922269
# 677                                             Erminia                1142922
# 547                                    Gli avventurieri                6435055
# 1022  Il Pastor fido, tragicomedia pastorale del sig...              Not found
#
# [5 rows x 30 columns]

# %%
expr = r'''favola pastorale|fauola musicale|burletta in musica|componimento sagro|azione musicale|componimento sacro|spettacolo fantastico|scena in versi|fauola tragicomica|fauola pastorale|diuertimento comico|azione romantica|intermezzo in musica|intermezzi|favola in prosa|componimento sagro|componimento|azione sacra|actio sacra|libretto fantastico|opera|tragedia|farsa|commeddia|commedia|operetta|festa|cantata|dramma|drama|melodramma|melodrama|melo-dramma|oratorio|libretto|fiaba|fauola|favola'''
locations['genre_opera'] = [re.search(expr,s.lower()).group(0) if re.search(expr,s.lower()) else 'Not found' for s in locations.title]

gergo2it = {'fauola':'favola', 'drama':'dramma', 'melodrama':'melodramma', 
            'melo-dramma':'melodramma', 'actio sacra':'azione sacra', 'componimento sagro':'componimento sacro',
            'fauola pastorale':'favola pastorale', 'commeddia':'commedia', 'diuertimento comico':'divertimento comico',
            'fauola tragicomica': 'favola tragicomica'
           }
locations['genre_opera'] = locations['genre_opera'].map(lambda x: gergo2it[x] if x in gergo2it.keys() else x)
locations.genre_opera.value_counts()
# Out:
# dramma                   710
# melodramma                89
# Not found                 55
# tragedia                  42
# componimento sacro        37
# farsa                     29
# opera                     25
# azione sacra              21
# oratorio                  19
# festa                     12
# commedia                  11
# cantata                   11
# intermezzi                 8
# favola pastorale           7
# componimento               7
# libretto                   5
# favola                     5
# operetta                   4
# fiaba                      2
# fauola musicale            1
# spettacolo fantastico      1
# azione musicale            1
# divertimento comico        1
# scena in versi             1
# libretto fantastico        1
# favola tragicomica         1
# favola in prosa            1
# burletta in musica         1
# intermezzo in musica       1
# azione romantica           1
# Name: genre_opera, dtype: int64

# %%
nlp = spacy.load("it_core_news_sm")
locations['genre_vec_method_1'] = [np.mean(np.array([token.vector for token in nlp(loc)]), axis=0) for loc in locations.genre_opera]
print('Processed the set')

NUM_CLUSTERS = 15
kmeans = KMeans(n_clusters=NUM_CLUSTERS, random_state=0, max_iter=500, verbose=10000).fit(locations['genre_vec_method_1'].tolist())
# Out:
# Processed the set
# Initialization complete
# Iteration 0, inertia 16061.076542260764
# Iteration 1, inertia 13226.865880966596
# Iteration 2, inertia 13195.09129230648
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 15712.991658011408
# Iteration 1, inertia 11817.625426569226
# Iteration 2, inertia 11787.777340259454
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 13984.209133167722
# Iteration 1, inertia 11794.77631444457
# Iteration 2, inertia 11765.676743042563
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 14924.019186460195
# Iteration 1, inertia 11258.527757515667
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 13984.209133167722
# Iteration 1, inertia 11794.77631444457
# Iteration 2, inertia 11765.676743042563
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 13984.209133167722
# Iteration 1, inertia 11794.77631444457
# Iteration 2, inertia 11765.676743042563
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 14042.669538450498
# Iteration 1, inertia 11272.062047590345
# Iteration 2, inertia 11242.962476188339
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 14865.558781177418
# Iteration 1, inertia 11781.242024369907
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 14986.159456059311
# Iteration 1, inertia 12826.259096328487
# Iteration 2, inertia 12797.159524926483
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 14865.558781177418
# Iteration 1, inertia 11781.242024369907
# Converged at iteration 1: strict convergence.

# %%
locations['predicted_genre_cluster_method_1'] = locations['genre_vec_method_1'].apply(lambda x: kmeans.predict([x.tolist()])[0])
locations['predicted_genre_cluster_method_1']
# Out:
# 0       0
# 1       0
# 2       2
# 3       4
# 4       0
#        ..
# 1105    0
# 1106    0
# 1107    0
# 1108    0
# 1109    0
# Name: predicted_genre_cluster_method_1, Length: 1110, dtype: int64

# %%
cluster_genre = {}
for i, cluster in enumerate(locations.predicted_genre_cluster_method_1):
    if cluster in cluster_genre.keys():
        if locations.genre_opera[i] != 'Not found':
            cluster_genre[cluster].append(locations.genre_opera[i])
    else:
            cluster_genre[cluster] = [locations.genre_opera[i]]

# %%
cluster_genre
# Out:
# {0: ['dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma',
#   'dramma'],
#  2: ['melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma',
#   'melodramma'],
#  4: ['componimento sacro',
#   'spettacolo fantastico',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'divertimento comico',
#   'componimento',
#   'componimento sacro',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro',
#   'componimento sacro'],
#  3: ['Not found'],
#  5: ['opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera',
#   'opera'],
#  7: ['farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa',
#   'farsa'],
#  6: ['tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia',
#   'tragedia'],
#  1: ['azione romantica',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'fiaba',
#   'azione sacra',
#   'intermezzo in musica',
#   'azione sacra',
#   'azione sacra',
#   'burletta in musica',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra',
#   'fiaba',
#   'azione sacra',
#   'azione sacra',
#   'scena in versi',
#   'favola in prosa',
#   'azione sacra',
#   'azione sacra',
#   'azione sacra'],
#  10: ['festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa',
#   'festa'],
#  11: ['operetta',
#   'commedia',
#   'commedia',
#   'commedia',
#   'commedia',
#   'commedia',
#   'operetta',
#   'commedia',
#   'commedia',
#   'commedia',
#   'commedia',
#   'commedia',
#   'commedia',
#   'operetta',
#   'operetta'],
#  12: ['cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata',
#   'cantata'],
#  8: ['oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio',
#   'oratorio'],
#  14: ['favola',
#   'favola pastorale',
#   'favola',
#   'favola pastorale',
#   'favola pastorale',
#   'favola',
#   'fauola musicale',
#   'azione musicale',
#   'favola pastorale',
#   'favola tragicomica',
#   'favola pastorale',
#   'favola',
#   'favola',
#   'favola pastorale',
#   'favola pastorale'],
#  13: ['libretto',
#   'libretto',
#   'libretto',
#   'libretto fantastico',
#   'libretto',
#   'libretto'],
#  9: ['intermezzi',
#   'intermezzi',
#   'intermezzi',
#   'intermezzi',
#   'intermezzi',
#   'intermezzi',
#   'intermezzi',
#   'intermezzi']}

# %%
for k in cluster_genre.keys():
    cluster_genre[k] = max(set(cluster_genre[k]), key=cluster_genre[k].count)
    
cluster_genre
# Out:
# {0: 'dramma',
#  2: 'melodramma',
#  4: 'componimento sacro',
#  3: 'Not found',
#  5: 'opera',
#  7: 'farsa',
#  6: 'tragedia',
#  1: 'azione sacra',
#  10: 'festa',
#  11: 'commedia',
#  12: 'cantata',
#  8: 'oratorio',
#  14: 'favola pastorale',
#  13: 'libretto',
#  9: 'intermezzi'}

# %%
locations['inferred_genre'] = [cluster_genre[cluster] for cluster in locations.predicted_genre_cluster_method_1]
locations.inferred_genre.value_counts()
# Out:
# dramma                710
# melodramma             89
# Not found              55
# componimento sacro     46
# tragedia               42
# farsa                  29
# azione sacra           28
# opera                  25
# oratorio               19
# favola pastorale       15
# commedia               15
# festa                  12
# cantata                11
# intermezzi              8
# libretto                6
# Name: inferred_genre, dtype: int64

# %%
S = requests.Session()
URL = "https://it.wikipedia.org/w/api.php"

# %%
locations['genre_mediawiki_pageid'] = [S.get(url=URL, params={"action": "query",
                                                              "format": "json",
                                                              "list": "search",
                                                              "srsearch": title}).json()
                                            ['query']['search'][0]['pageid'] 
                                       if len(S.get(url=URL, params={"action": "query",
                                                                     "format": "json",
                                                                     "list": "search",
                                                                     "srsearch": title}).json()
                                              ['query']['search']) > 0
                                       else
                                           'Not found'
                                       for title in locations.inferred_genre
                                       ]
locations['genre_mediawiki_pageid']
# Out:
# 0        375957
# 1        375957
# 2       2615411
# 3        710671
# 4        375957
#          ...
# 1105     375957
# 1106     375957
# 1107     375957
# 1108     375957
# 1109     375957
# Name: genre_mediawiki_pageid, Length: 1110, dtype: int64

# %%
locations.to_csv('./data/librettos_theaters.csv', sep='\t')
